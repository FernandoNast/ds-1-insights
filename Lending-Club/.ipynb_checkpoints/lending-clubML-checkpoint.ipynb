# %%
import pandas            as pd
import numpy             as np
import seaborn           as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics         import confusion_matrix, roc_auc_score, roc_curve, plot_roc_curve
from sklearn                 import metrics

# %%
data_raw = pd.read_csv('loan_data.csv')
data_raw.head()
# Out:
# C:\Users\Fernando Nast\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (19,55,112,123,124,125,128,129,130,133,139,140,141) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0 NaN        NaN      20975        20975            20975  36 months
# 1 NaN        NaN      20000        20000            20000  36 months
# 2 NaN        NaN       9100         9100             9100  36 months
# 3 NaN        NaN       3525         3525             3525  36 months
# 4 NaN        NaN      11500        11500            11500  36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0      8.19       659.13     A        A4  ...                            NaN
# 1     11.80       662.38     B        B4  ...                            NaN
# ...

# %%
data_raw.columns.values
# Out:
# array(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'pymnt_plan',
#        'url', 'desc', 'purpose', 'title', 'zip_code', 'addr_state', 'dti',
#        'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'mths_since_last_record', 'open_acc',
#        'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_d', 'last_pymnt_amnt', 'next_pymnt_d',
#        'last_credit_pull_d', 'collections_12_mths_ex_med',
#        'mths_since_last_major_derog', 'policy_code', 'application_type',
# ...

# %% [markdown]
# Pra saber qual das colunas correspondia às datas desejadas, há o arquivo dicionário, explicando as variáveis (``LCDataDictionary.xlsx``)

# %%
df1 = data_raw.copy()
dt1 = pd.to_datetime(df1['issue_d'])
df1['year'] = dt1.dt.year

# %%
df1.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0 NaN        NaN      20975        20975            20975  36 months
# 1 NaN        NaN      20000        20000            20000  36 months
# 2 NaN        NaN       9100         9100             9100  36 months
# 3 NaN        NaN       3525         3525             3525  36 months
# 4 NaN        NaN      11500        11500            11500  36 months
#
#    int_rate  installment grade sub_grade  ... hardship_last_payment_amount  \
# 0      8.19       659.13     A        A4  ...                          NaN
# 1     11.80       662.38     B        B4  ...                          NaN
# 2     26.31       368.15     E        E4  ...                          NaN
# 3     25.34       140.79     E        E3  ...                          NaN
# 4     13.56       390.59     C        C1  ...                          NaN
#
#   disbursement_method debt_settlement_flag  debt_settlement_flag_date  \
# ...

# %%
df1['complete_date'] = pd.to_datetime(df1['issue_d'])
df1['complete_date'].head()
# Out:
# 0   2018-12-01
# 1   2018-12-01
# 2   2018-12-01
# 3   2018-12-01
# 4   2018-12-01
# Name: complete_date, dtype: datetime64[ns]

# %%
# Agrupando os estados em regioes, fazendo assim diminuir a quantidade de valores
df2 = df1.copy()

oeste = ['CA', 'OR', 'UT','WA', 'CO', 'NV', 'AK', 'MT', 'HI', 'WY', 'ID']
sudoeste = ['AZ', 'TX', 'NM', 'OK']
sudeste = ['GA', 'NC', 'VA', 'FL', 'KY', 'SC', 'LA', 'AL', 'WV', 'DC', 'AR', 'DE', 'MS', 'TN' ]
centro_oeste = ['IL', 'MO', 'MN', 'OH', 'WI', 'KS', 'MI', 'SD', 'IA', 'NE', 'IN', 'ND']
nordeste = ['CT', 'NY', 'PA', 'NJ', 'RI','MA', 'MD', 'VT', 'NH', 'ME']

def finding_regions(state):
    if state in oeste:
        return 'Oeste'
    elif state in sudoeste:
        return 'Sudoeste'
    elif state in sudeste:
        return 'Sudeste'
    elif state in centro_oeste:
        return 'Centro_oeste'
    elif state in nordeste:
        return 'Nordeste'
    
df2['regiao'] = df2['addr_state'].apply(finding_regions)

# %%
df2.head()
# Out:
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0 NaN        NaN      20975        20975            20975  36 months
# 1 NaN        NaN      20000        20000            20000  36 months
# 2 NaN        NaN       9100         9100             9100  36 months
# 3 NaN        NaN       3525         3525             3525  36 months
# 4 NaN        NaN      11500        11500            11500  36 months
#
#    int_rate  installment grade sub_grade  ... debt_settlement_flag  \
# 0      8.19       659.13     A        A4  ...                    N
# 1     11.80       662.38     B        B4  ...                    N
# 2     26.31       368.15     E        E4  ...                    N
# 3     25.34       140.79     E        E3  ...                    N
# 4     13.56       390.59     C        C1  ...                    N
#
#   debt_settlement_flag_date settlement_status  settlement_date  \
# 0                       NaN               NaN              NaN
# ...

# %% [markdown]
# ## Verificando os NaNs

# %%
# len(data_raw) = 248196

colunas = data_raw.columns
df3 = df2.copy()

count = 0
for col in colunas:
    if (df3[str(col)].isnull().sum()>=21000): # Selecionei 21000 pq acima disso tem-se 99% nulos, abaixo disso o que mais tem nulos, chega a 8%
        print(str(col))
        print(df3[str(col)].isnull().sum())
        print(df3[str(col)].isnull().sum()/len(df3))
        print('\n')
        count=count+1
        
print('Quantidade de colunas com mais de 21k NaN -',count)
# Out:
# id
# 248196
# 1.0
#
#
# member_id
# 248196
# 1.0
#
#
# url
# 248196
# 1.0
#
#
# desc
# 248175
# 0.9999153894502731
#
#
# mths_since_last_delinq
# 234498
# 0.9448097471353285
#
#
# mths_since_last_major_derog
# 240217
# 0.9678520201776015
#
#
# annual_inc_joint
# 245594
# 0.9895163499814663
#
#
# dti_joint
# 245594
# 0.9895163499814663
#
#
# verification_status_joint
# 245622
# 0.9896291640477687
#
#
# mths_since_recent_bc_dlq
# 241542
# 0.9731905429579848
#
#
# mths_since_recent_revol_delinq
# 238917
# 0.9626142242421312
#
#
# revol_bal_joint
# 245811
# 0.9903906589953102
#
#
# sec_app_earliest_cr_line
# 245811
# 0.9903906589953102
#
#
# sec_app_inq_last_6mths
# 245811
# 0.9903906589953102
#
#
# sec_app_mort_acc
# 245811
# 0.9903906589953102
#
#
# sec_app_open_acc
# 245811
# 0.9903906589953102
#
#
# sec_app_revol_util
# 245868
# 0.9906203162017115
#
#
# sec_app_open_act_il
# 245811
# 0.9903906589953102
#
#
# sec_app_num_rev_accts
# 245811
# 0.9903906589953102
#
#
# ...

# %%
df3 = df3.dropna(axis=1,thresh=(0.0846*len(data_raw)))

# %%
df3.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      20975        20975            20975  36 months      8.19       659.13
# 1      20000        20000            20000  36 months     11.80       662.38
# 2       9100         9100             9100  36 months     26.31       368.15
# 3       3525         3525             3525  36 months     25.34       140.79
# 4      11500        11500            11500  36 months     13.56       390.59
#
#   grade sub_grade                emp_title emp_length  ... tot_hi_cred_lim  \
# 0     A        A4         Project Director    2 years  ...          378104
# 1     B        B4         Dental Hygienist    3 years  ...          164900
# 2     E        E4            Rural carrier    3 years  ...           67696
# 3     E        E3  chief marketing officer  10+ years  ...           99054
# 4     C        C1   Senior Client Advocate    8 years  ...           13000
#
# ...

# %%
# Agrupar Default, Late em 1 e Current em 0. Ou seja, 1 é para os que atrasaram e 0 é o que está em dia

df4 = df3.copy()

def troca_valores(row):
    if((row['loan_status']=='Default')|(row['loan_status']=='Late (31-120 days)')|(row['loan_status']=='Late (16-30 days)')):
        return 1
    else:
        return 0
    
df4['loan_status'] = df3.apply(df3,axis=1)

# %%
df4.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv       term  int_rate  installment  \
# 0      20975        20975            20975  36 months      8.19       659.13
# 1      20000        20000            20000  36 months     11.80       662.38
# 2       9100         9100             9100  36 months     26.31       368.15
# 3       3525         3525             3525  36 months     25.34       140.79
# 4      11500        11500            11500  36 months     13.56       390.59
#
#   grade sub_grade                emp_title emp_length  ... percent_bc_gt_75  \
# 0     A        A4         Project Director    2 years  ...              0.0
# 1     B        B4         Dental Hygienist    3 years  ...              0.0
# 2     E        E4            Rural carrier    3 years  ...              0.0
# 3     E        E3  chief marketing officer  10+ years  ...              0.0
# 4     C        C1   Senior Client Advocate    8 years  ...              NaN
#
# ...

# %%
for col in df4.columns.values:
    if (df4[str(col)].isnull().sum()>0): 
        print(str(col))
        print('Qtd Absoluta:',df4[str(col)].isnull().sum())
        print('Qtd %:', df4[str(col)].isnull().sum()/len(df4))
        print('Media:',df4[str(col)].mean())
        print('Mediana:',df4[str(col)].median())
        print('\n')
# Out:
# emp_title
# Qtd Absoluta: 2529
# Qtd % 0.010189527631388097
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-32c7ba098346> in <module>
#       4         print('Qtd Absoluta:',df4[str(col)].isnull().sum())
#       5         print('Qtd %', df4[str(col)].isnull().sum()/len(df4))
# ----> 6         print('Media:',df4[str(col)].mean())
#       7         print('Mediana:',df4[str(col)].median())
#       8         print('\n')
#
# ~\miniconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11454         if level is not None:
#   11455             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11456         return self._reduce(
#   11457             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11458         )
#
# ...

# %%
# Estava iniciando a busca pelas features numericas, para iniciar a inputação dos valores nulos...
import
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-e3e56c2fad1d> in <module>
# ----> 1 df4.corr.columns
#
# AttributeError: 'function' object has no attribute 'columns'
